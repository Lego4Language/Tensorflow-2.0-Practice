# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# sys.version_info(major=3, minor=7, micro=5, releaselevel='final', serial=0)
# matplotlib 3.1.2
# numpy 1.17.4
# pandas 0.25.3
# sklearn 0.22
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %% [markdown]
# ## 1. 准备并处理数据

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
print(housing.data.shape)
print(housing.target.shape)
# Out:
# (20640, 8)
# (20640,)

# %%
import pprint

pprint.pprint(housing.data[0:5])
pprint.pprint(housing.target[0:5])
# Out:
# array([[ 8.32520000e+00,  4.10000000e+01,  6.98412698e+00,
#          1.02380952e+00,  3.22000000e+02,  2.55555556e+00,
#          3.78800000e+01, -1.22230000e+02],
#        [ 8.30140000e+00,  2.10000000e+01,  6.23813708e+00,
#          9.71880492e-01,  2.40100000e+03,  2.10984183e+00,
#          3.78600000e+01, -1.22220000e+02],
#        [ 7.25740000e+00,  5.20000000e+01,  8.28813559e+00,
#          1.07344633e+00,  4.96000000e+02,  2.80225989e+00,
#          3.78500000e+01, -1.22240000e+02],
#        [ 5.64310000e+00,  5.20000000e+01,  5.81735160e+00,
#          1.07305936e+00,  5.58000000e+02,  2.54794521e+00,
#          3.78500000e+01, -1.22250000e+02],
#        [ 3.84620000e+00,  5.20000000e+01,  6.28185328e+00,
#          1.08108108e+00,  5.65000000e+02,  2.18146718e+00,
#          3.78500000e+01, -1.22250000e+02]])
# array([4.526, 3.585, 3.521, 3.413, 3.422])

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data, housing.target, 
                                                            random_state= 7)
x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all, 
                                                      random_state = 11)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ## 2.【重点】 模型构建(多输入）

# %%
input_wide = keras.layers.Input(shape=[5])
input_deep = keras.layers.Input(shape=[6])
hidden1 = keras.layers.Dense(30, activation="relu")(input_deep)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_wide, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs=[input_wide, input_deep], outputs = [output])
 
model.summary()
model.compile(loss="mean_squared_error", optimizer="Adam")
callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2)]
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           210         input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           930         dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35)           0           input_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            36          concatenate[0][0]
# ==================================================================================================
# Total params: 1,176
# Trainable params: 1,176
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. 训练模型

# %%
x_train_scaled_wide = x_train_scaled[:, :5]
x_train_scaled_deep = x_train_scaled[:, 2:]
x_valid_scaled_wide = x_valid_scaled[:, :5]
x_valid_scaled_deep = x_valid_scaled[:, 2:]
x_test_scaled_wide = x_test_scaled[:, :5]
x_test_scaled_deep = x_test_scaled[:, 2:]

history = model.fit([x_train_scaled_wide, x_train_scaled_deep], 
                    y_train, 
                   validation_data = ([x_valid_scaled_wide, x_valid_scaled_deep], y_valid),
                   epochs = 100,
                   callbacks = callbacks)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 1.7570 - val_loss: 0.7090
# Epoch 2/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.5497 - val_loss: 0.5014
# Epoch 3/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.4615 - val_loss: 0.4567
# Epoch 4/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.4168 - val_loss: 0.4320
# Epoch 5/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3920 - val_loss: 0.3964
# Epoch 6/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3670 - val_loss: 0.3799
# Epoch 7/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3559 - val_loss: 0.3676
# Epoch 8/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3598 - val_loss: 0.3672
# Epoch 9/100
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.3474 - val_loss: 0.3587
# Epoch 10/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3483 - val_loss: 0.3845
# Epoch 11/100
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.3365 - val_loss: 0.3581
# Epoch 12/100
# 11610/11610 [==============================] - 0s 38us/sample - loss: 0.3347 - val_loss: 0.3465
# Epoch 13/100
# 11610/11610 [==============================] - 1s 49us/sample - loss: 0.3363 - val_loss: 0.3421
# Epoch 14/100
# 11610/11610 [==============================] - 1s 43us/sample - loss: 0.3331 - val_loss: 0.3462
# Epoch 15/100
# 11610/11610 [==============================] - 1s 53us/sample - loss: 0.3307 - val_loss: 0.3394
# Epoch 16/100
# 11610/11610 [==============================] - 0s 43us/sample - loss: 0.3350 - val_loss: 0.3400
# Epoch 17/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3240 - val_loss: 0.3319
# Epoch 18/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3250 - val_loss: 0.3336
# Epoch 19/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3190 - val_loss: 0.3314
# Epoch 20/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3219 - val_loss: 0.3536
# Epoch 21/100
# 11610/11610 [==============================] - 0s 40us/sample - loss: 0.3180 - val_loss: 0.3396
# Epoch 22/100
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.3216 - val_loss: 0.3302

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
plot_learning_curves(history)

# %% [markdown]
# ## 4. 模型预测

# %%
model.evaluate([x_test_scaled_wide, x_test_scaled_deep], y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.3442273702270301
